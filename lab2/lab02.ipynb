# %% [markdown]
# # TNM112 -- Lab 2

# %% [markdown]
# ### Data generation
# Look through the "data_generator.py" code to understand how the dataset is generated and plotted.
#
# A dataset can be generated with a randomly selected subset of training images, and with a specified fraction used to formulate a validation set. Here, we use the MNIST dataset of handwritten digits.

# %%
import data_generator

data = data_generator.DataGenerator()
data.generate(dataset='mnist', N_valid=0.1)
data.plot()
# Out:
# Data specification:
# 	Dataset type:           mnist
# 	Number of classes:      10
# 	Number of channels:     1
# 	Training data shape:    (54000, 28, 28, 1)
# 	Validation data shape:  (6000, 28, 28, 1)
# 	Test data shape:        (10000, 28, 28, 1)

# %% [markdown]
# ### Keras CNN
# A small CNN in Keras, trained with cross-entropy loss
#
# We use the functions in 'util.py' to evaluate the model and plot the training progress.

# %%
from tensorflow import keras
from tensorflow.keras import layers
import util

keras.backend.clear_session()

model = keras.Sequential()
model.add(layers.InputLayer(input_shape=data.x_train.shape[1:]))
model.add(layers.Conv2D(4, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Conv2D(8, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(data.K, activation='softmax'))
model.summary()

opt = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
log = model.fit(data.x_train, data.y_train_oh, batch_size=128, epochs=10, 
                validation_data=(data.x_valid, data.y_valid_oh), verbose=True)

util.evaluate(model, data, final=True)
util.plot_training(log)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 4)         40
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 4)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 8)         296
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 8)          0
#  2D)
#
#  flatten (Flatten)           (None, 392)               0
#
#  dense (Dense)               (None, 10)                3930
#
# =================================================================
# Total params: 4,266
# Trainable params: 4,266
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 422/422 [==============================] - 30s 68ms/step - loss: 0.5471 - accuracy: 0.8519 - val_loss: 0.1917 - val_accuracy: 0.9448
# Epoch 2/10
# 422/422 [==============================] - 23s 54ms/step - loss: 0.1536 - accuracy: 0.9545 - val_loss: 0.1313 - val_accuracy: 0.9593
# Epoch 3/10
# 422/422 [==============================] - 25s 60ms/step - loss: 0.1141 - accuracy: 0.9659 - val_loss: 0.1128 - val_accuracy: 0.9638
# Epoch 4/10
# 422/422 [==============================] - 25s 59ms/step - loss: 0.0971 - accuracy: 0.9704 - val_loss: 0.0953 - val_accuracy: 0.9725
# Epoch 5/10
# 422/422 [==============================] - 29s 68ms/step - loss: 0.0863 - accuracy: 0.9730 - val_loss: 0.0841 - val_accuracy: 0.9755
# Epoch 6/10
# 422/422 [==============================] - 29s 69ms/step - loss: 0.0782 - accuracy: 0.9756 - val_loss: 0.0784 - val_accuracy: 0.9768
# Epoch 7/10
# 422/422 [==============================] - 26s 62ms/step - loss: 0.0718 - accuracy: 0.9777 - val_loss: 0.0749 - val_accuracy: 0.9773
# Epoch 8/10
# 422/422 [==============================] - 26s 61ms/step - loss: 0.0668 - accuracy: 0.9795 - val_loss: 0.0752 - val_accuracy: 0.9783
# Epoch 9/10
# 422/422 [==============================] - 24s 57ms/step - loss: 0.0633 - accuracy: 0.9801 - val_loss: 0.0728 - val_accuracy: 0.9783
# Epoch 10/10
# 422/422 [==============================] - 26s 62ms/step - loss: 0.0606 - accuracy: 0.9813 - val_loss: 0.0751 - val_accuracy: 0.9762
# Model performance:
# 	Train loss:          0.0594
# 	Train accuracy:      98.09
# 	Test loss:           0.0627
# 	Test accuracy:       97.94

# %% [markdown]
# ### Our CNN
#
# #### Task 1
# Implement the following functions in cnn.py: 'activation', 'conv2d_layer', 'pool2d_layer', 'flatten_layer', 'dense_layer', and 'evaluate'. Additionally, compute the number of weights in the model, in the function 'setup_model'.
#
# For the 'activation' and 'dense_layer' functions you can use code that you wrote in Lab 1. For the 'evaluate' function you can use the code from Lab 1 for the accuracy. However, now we have trained with the cross-entropy loss, so you should evaluate this loss function through our CNN.
#
# When you have finished the implementation, you should be able to run this code and get the same result as with the Keras model above. However, our code is not optimized, nor parallelized, so it will be rather slow to process the full dataset. In order to facilitate comparisons when you implement the functions, please have a look in the next cell below.

# %%
import importlib
import cnn
importlib.reload(cnn)

# Get the weight matrices and biases of the trained Keras model
W, b, lname = util.get_weights(model)
print(lname)

# This is our implementation of a CNN, which we set to use the dataset we generated
cnn = cnn.CNN(data, verbose=True)

# Assign the weights and biases to the CNN and specify the activation function
cnn.setup_model(W, b, lname, activation='relu')

# Evaluate the model (accuracy on the training and test data)
cnn.evaluate()
# Out:
# ['conv', 'pool', 'conv', 'pool', 'flatten', 'dense']
# Number of model weights:  4266
# Model performance:
# sample 0 of 54000
# sample 1000 of 54000
# sample 2000 of 54000
# sample 3000 of 54000
# sample 4000 of 54000
# sample 5000 of 54000
# sample 6000 of 54000
# sample 7000 of 54000
# sample 8000 of 54000
# sample 9000 of 54000
# sample 10000 of 54000
# sample 11000 of 54000
# sample 12000 of 54000
# sample 13000 of 54000
# sample 14000 of 54000
# sample 15000 of 54000
# sample 16000 of 54000
# sample 17000 of 54000
# sample 18000 of 54000
# sample 19000 of 54000
# sample 20000 of 54000
# sample 21000 of 54000
# sample 22000 of 54000
# sample 23000 of 54000
# sample 24000 of 54000
# sample 25000 of 54000
# sample 26000 of 54000
# sample 27000 of 54000
# sample 28000 of 54000
# sample 29000 of 54000
# sample 30000 of 54000
# sample 31000 of 54000
# sample 32000 of 54000
# sample 33000 of 54000
# sample 34000 of 54000
# sample 35000 of 54000
# sample 36000 of 54000
# sample 37000 of 54000
# sample 38000 of 54000
# sample 39000 of 54000
# sample 40000 of 54000
# sample 41000 of 54000
# sample 42000 of 54000
# sample 43000 of 54000
# sample 44000 of 54000
# sample 45000 of 54000
# sample 46000 of 54000
# sample 47000 of 54000
# sample 48000 of 54000
# sample 49000 of 54000
# sample 50000 of 54000
# sample 51000 of 54000
# sample 52000 of 54000
# sample 53000 of 54000
# 	Train loss:     0.0594
# 	Train accuracy: 0.98
# sample 0 of 10000
# sample 1000 of 10000
# sample 2000 of 10000
# sample 3000 of 10000
# sample 4000 of 10000
# sample 5000 of 10000
# sample 6000 of 10000
# sample 7000 of 10000
# sample 8000 of 10000
# sample 9000 of 10000
# 	Test loss:      0.0627
# 	Test accuracy:  0.98

# %% [markdown]
# ### Evaluation of our CNN layers
#
# #### Task 1
# As part of the implementation of the different layers in 'cnn.py', you can use the below code to compare the output of a randomly initialized Keras model and our CNN, for a single image. This is fast to compute, which will be convenient to check that your layers are correctly implemented.

# %%
import importlib
import numpy as np
import cnn
importlib.reload(cnn)

# Secify a test layer for comparison: 'conv', 'pool', 'flatten', or 'dense'
# TODO: fix dense and the dimentions of uptput in feedforward_sample, so all layers
test_layer = 'dense'

keras.backend.clear_session()

# Keras model and input layer
model = keras.Sequential()
model.add(layers.InputLayer(input_shape=data.x_train.shape[1:]))

# Test conv layer
#   - We apply normal initialization to the bias also,
#     otherwise it would be difficult to see the impact
#     of how you apply the bias (it is initialized to 0 by default)
if test_layer == 'conv':
    model.add(layers.Conv2D(4, kernel_size=(3, 3), 
                            activation='relu', padding='same',
                            bias_initializer='normal'))
    
    # You could also test to add a second convolutional layer, to check
    # that your network maps correctly from the output channels of the
    # previous layer, to the channels of this layer
    #model.add(layers.Conv2D(4, kernel_size=(3, 3), 
    #                        activation='relu', padding='same',
    #                        bias_initializer='normal'))

# Test pooling layer
elif test_layer == 'pool':
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# Test flattening layer
elif test_layer == 'flatten':
    model.add(layers.Flatten())

# Test dense layer
#   - We need to first flatten the image input to apply a dense layer
#   - Make sure that your flatten layer works before testing the dense layer
elif test_layer == 'dense':
    model.add(layers.Flatten())
    model.add(layers.Dense(10, activation='softmax',
                           bias_initializer='normal'))

# Test data point (you could select any other image if you want)
x = data.x_train[0]

# Keras prediction. We need ta add an extra axis, 
# since the model can run over multiple datapoints. We 
# would need this in our model also if we use used the
# 'feedforward' function instead of the 'feedforward_sample'
y1 = model.predict(x[np.newaxis,:,:,:], verbose=False)

# Prediction with our network
W, b, lname = util.get_weights(model)  # Get the Keras model weights
cnn = cnn.CNN(data)
cnn.setup_model(W, b, lname, activation='relu') # Assign weights to our model
y2 = cnn.feedforward_sample(x) # Feedforward of one single sample

print('Evaluation of %s layer:'%test_layer)

# Check that the dimensionality is correct. The Keras
# model will have an extra first dimension due to the
# batch processing
print('\tShape of Keras output:  ', y1.shape)
print('\tShape of our output:    ', y2.shape)

# Print the absolute sum of output from the Keras
# model and our model. These should be the same if the
# implementation is correct
print('\tAbs sum of Keras model: ', np.sum(np.abs(y1)))
print('\tAbs sum of our model:   ', np.sum(np.abs(y2)))

# Print the absolute difference between the Keras
# model and our model. This should be very close
# to 0 if your implementation is correct. It could be
# a very minor difference due to numerical differences 
# (e.g., difference in precision used)
print('\tAbs difference:         ', np.sum(np.abs(y1-y2)))
# Out:
# Number of model weights:  7850
# Evaluation of dense layer:
# 	Shape of Keras output:   (1, 10)
# 	Shape of our output:     (10,)
# 	Abs sum of Keras model:  1.0
# 	Abs sum of our model:    1.0
# 	Abs difference:          1.1455268e-07

# %% [markdown]
# ### MNIST with limited training data
# #### Task 2
# In this experiment, we select a random subset from MNIST, with only 128 images. This is a very minimal dataset, but it is interesting to see how overfitting can be prevented with regularization strategies.
#
# Your task is to expand the given network with different regularization strategies. You are free to choose which combination of strategies you want to use, for example augmentation layers, dropout, weight decay, batch normalization, etc. You can also expand the network with more layers, strided convolutions, or add skip-connections to facilitate optimization. Moreover, you can experiment with the number of training epochs and the batch size.
#
# Also, note that now we have specified the Keras network in a sligthly different way. We explicitly formulate the input and output to the different layers. One motiviation for this is that it is easier if we want to, e.g., add skip-connections (checkout the layers.Add() layer in Keras).
#
# During your development, you test the performance on the validation set (util.evaluate with the flag final=False). When you have found a good setup, run evaluation on the test set (final=True). Do this for at least 5 runs and report the average and the variance across models. Since the subset of 128 images is randomly selected and the optimization is stochastic, you will get slightly different values each time. Thus, averaging is important to get a robust indication of your model's performance. You can do this manually, or you can setup a for-loop to run a sequence of trainings, where you log the evaluation results for each model.
#
# For the final results, you should aim at having an average accuracy of at least 90% (which is quite good considering that we are only training on 128 images).

# %%
# A block of convolutional layers followed by max pooling
def conv_block(x, N, channels, kernel_size, activation, padding='same'):
    for i in range(N):
        x = layers.Conv2D(channels, kernel_size=kernel_size, activation=activation, padding=padding, kernel_regularizer=keras.regularizers.l2(0.00001))(x)
    return layers.MaxPooling2D(pool_size=(2, 2))(x)
    
epochs = 250
batch_size = 16

# For setting up averaging over multiple training runs
K = 5
acc = np.zeros((K,2))
for k in range(K):

    # MNIST with 128 randomly selected training images
    data = data_generator.DataGenerator()
    data.generate(dataset='mnist', N_train=128)

    keras.backend.clear_session()

    x      = layers.Input(shape=data.x_train.shape[1:])
    # Augmentation layer crop
    augmented = layers.RandomCrop(height=data.x_train.shape[1], width=data.x_train.shape[2])(x)
    augmented = layers.RandomRotation(factor=0.1)(augmented)
    augmented = layers.RandomZoom(0.1)(augmented)
    conv1  = conv_block(augmented, N=2, channels=8, kernel_size=(3,3), activation='relu', padding='same')
    conv1 = keras.layers.Dropout(0.2)(conv1)
    conv2  = conv_block(conv1, N=2, channels=16, kernel_size=(3,3), activation='relu', padding='same')
    conv2 = keras.layers.Dropout(0.2)(conv2)
    conv3  = conv_block(conv2, N=2, channels=32, kernel_size=(3,3), activation='relu', padding='same')
    flat1  = layers.Flatten()(conv3)

    dense1 = layers.Dense(512, activation='relu')(flat1)
    # dropout layer
    dropout = keras.layers.Dropout(0.5)(dense1)
    # added kernel_regularizer
    y = layers.Dense(data.K, activation='softmax', kernel_regularizer=keras.regularizers.l2(0.0001))(dropout)

    model = keras.models.Model(inputs=x, outputs=y)
    model.summary()

    opt = keras.optimizers.Adam()
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    log = model.fit(data.x_train, data.y_train_oh, batch_size=batch_size, epochs=epochs, 
                    validation_data=(data.x_valid, data.y_valid_oh), validation_freq=10,  # We don't need to evaluate at each epoch
                    verbose=True)

    util.evaluate(model, data, final=False)
    util.plot_training(log)

    # When you are finished with hyper-parameter tuning, you should evaluate
    # your model on the test set, and average over 5 trainings. If you want
    # to do this automatically, you can setup a foor loop and store each evaluation
    acc[k,:] = util.evaluate(model, data, final=True)
print('Accuracy for each run: ', acc)
print('Average accuracy: ', np.mean(acc, axis=0))
# Out:
# Data specification:
# 	Dataset type:           mnist
# 	Number of classes:      10
# 	Number of channels:     1
# 	Training data shape:    (128, 28, 28, 1)
# 	Validation data shape:  (6000, 28, 28, 1)
# 	Test data shape:        (10000, 28, 28, 1)
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  random_crop (RandomCrop)    (None, 28, 28, 1)         0
#
#  random_rotation (RandomRota  (None, 28, 28, 1)        0
#  tion)
#
#  random_zoom (RandomZoom)    (None, 28, 28, 1)         0
#
#  conv2d (Conv2D)             (None, 28, 28, 8)         80
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 8)         584
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 8)        0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 8)         0
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 16)        1168
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 16)        2320
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 16)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 16)          0
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 32)          4640
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 32)          9248
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 288)               0
#
#  dense (Dense)               (None, 512)               147968
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 171,138
# Trainable params: 171,138
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/250
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 8/8 [==============================] - 22s 127ms/step - loss: 2.3211 - accuracy: 0.0469
# Epoch 2/250
# 8/8 [==============================] - 1s 165ms/step - loss: 2.3085 - accuracy: 0.0703
# Epoch 3/250
# 8/8 [==============================] - 1s 174ms/step - loss: 2.3046 - accuracy: 0.1406
# Epoch 4/250
# 8/8 [==============================] - 1s 167ms/step - loss: 2.2983 - accuracy: 0.1250
# Epoch 5/250
# 8/8 [==============================] - 2s 283ms/step - loss: 2.3018 - accuracy: 0.1328
# Epoch 6/250
# 8/8 [==============================] - 1s 179ms/step - loss: 2.2801 - accuracy: 0.1484
# Epoch 7/250
# 8/8 [==============================] - 1s 181ms/step - loss: 2.2600 - accuracy: 0.1250
# Epoch 8/250
# 8/8 [==============================] - 2s 194ms/step - loss: 2.1306 - accuracy: 0.2734
# Epoch 9/250
# 8/8 [==============================] - 1s 166ms/step - loss: 1.9718 - accuracy: 0.3125
# Epoch 10/250
# 8/8 [==============================] - 4s 547ms/step - loss: 1.8315 - accuracy: 0.4062 - val_loss: 1.3952 - val_accuracy: 0.5755
# Epoch 11/250
# 8/8 [==============================] - 1s 175ms/step - loss: 1.6437 - accuracy: 0.4219
# Epoch 12/250
# 8/8 [==============================] - 1s 182ms/step - loss: 1.5203 - accuracy: 0.4453
# Epoch 13/250
# 8/8 [==============================] - 2s 245ms/step - loss: 1.3038 - accuracy: 0.5781
# Epoch 14/250
# 8/8 [==============================] - 2s 267ms/step - loss: 1.2244 - accuracy: 0.6172
# Epoch 15/250
# 8/8 [==============================] - 3s 337ms/step - loss: 1.2226 - accuracy: 0.6250
# Epoch 16/250
# 8/8 [==============================] - 3s 393ms/step - loss: 1.1441 - accuracy: 0.6328
# Epoch 17/250
# 8/8 [==============================] - 2s 212ms/step - loss: 1.0878 - accuracy: 0.6797
# Epoch 18/250
# 8/8 [==============================] - 2s 272ms/step - loss: 0.9685 - accuracy: 0.7500
# Epoch 19/250
# 8/8 [==============================] - 2s 239ms/step - loss: 0.9974 - accuracy: 0.6562
# Epoch 20/250
# 8/8 [==============================] - 4s 621ms/step - loss: 0.9552 - accuracy: 0.6953 - val_loss: 0.6091 - val_accuracy: 0.8117
# Epoch 21/250
# 8/8 [==============================] - 2s 193ms/step - loss: 0.9476 - accuracy: 0.6797
# Epoch 22/250
# 8/8 [==============================] - 2s 201ms/step - loss: 0.6180 - accuracy: 0.7891
# Epoch 23/250
# 8/8 [==============================] - 2s 231ms/step - loss: 0.7489 - accuracy: 0.7734
# Epoch 24/250
# 8/8 [==============================] - 2s 198ms/step - loss: 0.7653 - accuracy: 0.7500
# Epoch 25/250
# 8/8 [==============================] - 2s 221ms/step - loss: 0.6540 - accuracy: 0.7969
# Epoch 26/250
# 8/8 [==============================] - 2s 200ms/step - loss: 0.8541 - accuracy: 0.6875
# Epoch 27/250
# 8/8 [==============================] - 2s 180ms/step - loss: 0.7358 - accuracy: 0.7656
# Epoch 28/250
# 8/8 [==============================] - 1s 186ms/step - loss: 0.7267 - accuracy: 0.7656
# 8/8 [==============================] - 2s 257ms/step - loss: 0.0476 - accuracy: 0.9844
# Epoch 227/250
# 8/8 [==============================] - 2s 240ms/step - loss: 0.0706 - accuracy: 0.9844
# Epoch 228/250
# 8/8 [==============================] - 1s 188ms/step - loss: 0.0726 - accuracy: 0.9688
# Epoch 229/250
# 8/8 [==============================] - 2s 229ms/step - loss: 0.0761 - accuracy: 0.9766
# Epoch 230/250
# 8/8 [==============================] - 4s 546ms/step - loss: 0.0410 - accuracy: 0.9922 - val_loss: 0.5664 - val_accuracy: 0.8967
# Epoch 231/250
# 8/8 [==============================] - 2s 246ms/step - loss: 0.0919 - accuracy: 0.9688
# Epoch 232/250
# 8/8 [==============================] - 2s 213ms/step - loss: 0.0922 - accuracy: 0.9766
# Epoch 233/250
# 8/8 [==============================] - 2s 232ms/step - loss: 0.0953 - accuracy: 0.9766
# Epoch 234/250
# 8/8 [==============================] - 2s 219ms/step - loss: 0.0690 - accuracy: 0.9922
# Epoch 235/250
# 8/8 [==============================] - 2s 234ms/step - loss: 0.0762 - accuracy: 0.9844
# Epoch 236/250
# 8/8 [==============================] - 2s 198ms/step - loss: 0.0526 - accuracy: 0.9766
# Epoch 237/250
# 8/8 [==============================] - 2s 187ms/step - loss: 0.0314 - accuracy: 0.9922
# Epoch 238/250
# 8/8 [==============================] - 2s 185ms/step - loss: 0.0786 - accuracy: 0.9844
# Epoch 239/250
# 8/8 [==============================] - 2s 245ms/step - loss: 0.0371 - accuracy: 0.9922
# Epoch 240/250
# 8/8 [==============================] - 3s 447ms/step - loss: 0.0576 - accuracy: 0.9844 - val_loss: 0.5080 - val_accuracy: 0.9038
# Epoch 241/250
# 8/8 [==============================] - 1s 165ms/step - loss: 0.0735 - accuracy: 0.9922
# Epoch 242/250
# 8/8 [==============================] - 1s 160ms/step - loss: 0.0574 - accuracy: 0.9766
# Epoch 243/250
# 8/8 [==============================] - 2s 197ms/step - loss: 0.0971 - accuracy: 0.9766
# Epoch 244/250
# 8/8 [==============================] - 1s 161ms/step - loss: 0.0609 - accuracy: 0.9922
# Epoch 245/250
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0658 - accuracy: 0.9766
# Epoch 246/250
# 8/8 [==============================] - 1s 152ms/step - loss: 0.0694 - accuracy: 0.9766
# Epoch 247/250
# 8/8 [==============================] - 1s 173ms/step - loss: 0.0708 - accuracy: 0.9844
# Epoch 248/250
# 8/8 [==============================] - 2s 193ms/step - loss: 0.1213 - accuracy: 0.9688
# Epoch 249/250
# 8/8 [==============================] - 1s 168ms/step - loss: 0.0465 - accuracy: 0.9922
# Epoch 250/250
# 8/8 [==============================] - 3s 463ms/step - loss: 0.0408 - accuracy: 0.9922 - val_loss: 0.5098 - val_accuracy: 0.9052
# Model performance:
# 	Train loss:          0.0174
# 	Train accuracy:      100.00
# 	Validation loss:     0.5098
# 	Validation accuracy: 90.52
# Model performance:
# 	Train loss:          0.0174
# 	Train accuracy:      100.00
# 	Test loss:           0.4933
# 	Test accuracy:       90.98
# Data specification:
# 	Dataset type:           mnist
# 	Number of classes:      10
# 	Number of channels:     1
# 	Training data shape:    (128, 28, 28, 1)
# 	Validation data shape:  (6000, 28, 28, 1)
# 	Test data shape:        (10000, 28, 28, 1)
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  random_crop (RandomCrop)    (None, 28, 28, 1)         0
#
#  random_rotation (RandomRota  (None, 28, 28, 1)        0
#  tion)
#
#  random_zoom (RandomZoom)    (None, 28, 28, 1)         0
#
#  conv2d (Conv2D)             (None, 28, 28, 8)         80
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 8)         584
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 8)        0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 8)         0
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 16)        1168
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 16)        2320
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 16)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 16)          0
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 32)          4640
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 32)          9248
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 288)               0
#
#  dense (Dense)               (None, 512)               147968
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 171,138
# Trainable params: 171,138
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/250
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 8/8 [==============================] - 21s 128ms/step - loss: 2.3372 - accuracy: 0.1875
# Epoch 2/250
# 8/8 [==============================] - 2s 215ms/step - loss: 2.3049 - accuracy: 0.1172
# Epoch 3/250
# 8/8 [==============================] - 1s 148ms/step - loss: 2.2797 - accuracy: 0.1797
# Epoch 4/250
# 8/8 [==============================] - 1s 181ms/step - loss: 2.2713 - accuracy: 0.1719
# Epoch 5/250
# 8/8 [==============================] - 1s 145ms/step - loss: 2.2695 - accuracy: 0.1797
# Epoch 6/250
# 8/8 [==============================] - 1s 164ms/step - loss: 2.2678 - accuracy: 0.1797
# Epoch 7/250
# 8/8 [==============================] - 1s 170ms/step - loss: 2.2670 - accuracy: 0.1797
# Epoch 8/250
# 8/8 [==============================] - 1s 155ms/step - loss: 2.2577 - accuracy: 0.1797
# Epoch 9/250
# 8/8 [==============================] - 1s 175ms/step - loss: 2.2604 - accuracy: 0.1797
# Epoch 10/250
# 8/8 [==============================] - 4s 531ms/step - loss: 2.2290 - accuracy: 0.1797 - val_loss: 2.2891 - val_accuracy: 0.1113
# Epoch 11/250
# 8/8 [==============================] - 1s 157ms/step - loss: 2.2233 - accuracy: 0.1797
# Epoch 12/250
# 8/8 [==============================] - 1s 173ms/step - loss: 2.1892 - accuracy: 0.1875
# Epoch 13/250
# 8/8 [==============================] - 1s 152ms/step - loss: 2.0951 - accuracy: 0.2500
# Epoch 14/250
# 8/8 [==============================] - 1s 152ms/step - loss: 2.0336 - accuracy: 0.2656
# Epoch 15/250
# 8/8 [==============================] - 1s 179ms/step - loss: 1.9762 - accuracy: 0.2656
# Epoch 16/250
# 8/8 [==============================] - 1s 173ms/step - loss: 1.8016 - accuracy: 0.3672
# Epoch 17/250
# 8/8 [==============================] - 1s 164ms/step - loss: 1.7388 - accuracy: 0.4453
# Epoch 18/250
# 8/8 [==============================] - 2s 190ms/step - loss: 1.7700 - accuracy: 0.4062
# Epoch 19/250
# 8/8 [==============================] - 2s 195ms/step - loss: 1.5496 - accuracy: 0.4922
# Epoch 20/250
# 8/8 [==============================] - 3s 424ms/step - loss: 1.2895 - accuracy: 0.5859 - val_loss: 1.1053 - val_accuracy: 0.6170
# Epoch 21/250
# 8/8 [==============================] - 1s 141ms/step - loss: 1.2630 - accuracy: 0.5781
# Epoch 22/250
# 8/8 [==============================] - 2s 218ms/step - loss: 1.1867 - accuracy: 0.6250
# Epoch 23/250
# 8/8 [==============================] - 1s 143ms/step - loss: 1.0812 - accuracy: 0.6328
# Epoch 24/250
# 8/8 [==============================] - 1s 152ms/step - loss: 0.9548 - accuracy: 0.6719
# Epoch 25/250
# 8/8 [==============================] - 1s 189ms/step - loss: 0.8984 - accuracy: 0.7109
# Epoch 26/250
# 8/8 [==============================] - 2s 222ms/step - loss: 0.8948 - accuracy: 0.6953
# Epoch 27/250
# 8/8 [==============================] - 1s 182ms/step - loss: 0.8419 - accuracy: 0.7500
# Epoch 28/250
# 8/8 [==============================] - 1s 168ms/step - loss: 0.7220 - accuracy: 0.7422
# Epoch 29/250
# 8/8 [==============================] - 2s 214ms/step - loss: 0.6742 - accuracy: 0.7969
# Epoch 30/250
# 8/8 [==============================] - 4s 484ms/step - loss: 0.6995 - accuracy: 0.8203 - val_loss: 0.6695 - val_accuracy: 0.7987
# Epoch 31/250
# 8/8 [==============================] - 1s 165ms/step - loss: 0.7013 - accuracy: 0.7266
# Epoch 32/250
# 8/8 [==============================] - 1s 169ms/step - loss: 0.5253 - accuracy: 0.7891
# Epoch 33/250
# 8/8 [==============================] - 2s 203ms/step - loss: 0.6521 - accuracy: 0.7578
# Epoch 34/250
# 8/8 [==============================] - 1s 188ms/step - loss: 0.6387 - accuracy: 0.7812
# Epoch 35/250
# 8/8 [==============================] - 2s 207ms/step - loss: 0.5615 - accuracy: 0.7891
# Epoch 36/250
# 8/8 [==============================] - 2s 212ms/step - loss: 0.5243 - accuracy: 0.8594
# Epoch 37/250
# 8/8 [==============================] - 2s 201ms/step - loss: 0.4650 - accuracy: 0.8672
# Epoch 38/250
# 8/8 [==============================] - 2s 175ms/step - loss: 0.4725 - accuracy: 0.8672
# Epoch 39/250
# 8/8 [==============================] - 1s 159ms/step - loss: 0.3865 - accuracy: 0.8828
# Epoch 40/250
# 8/8 [==============================] - 3s 430ms/step - loss: 0.3175 - accuracy: 0.8984 - val_loss: 0.5696 - val_accuracy: 0.8482
# Epoch 41/250
# 8/8 [==============================] - 1s 189ms/step - loss: 0.3004 - accuracy: 0.9062
# Epoch 42/250
# 8/8 [==============================] - 1s 153ms/step - loss: 0.5177 - accuracy: 0.8438
# Epoch 43/250
# 8/8 [==============================] - 1s 162ms/step - loss: 0.3426 - accuracy: 0.8828
# Epoch 44/250
# ...
# Epoch 104/250
# 8/8 [==============================] - 1s 183ms/step - loss: 0.0873 - accuracy: 0.9766
# Epoch 105/250
# 8/8 [==============================] - 1s 181ms/step - loss: 0.1246 - accuracy: 0.9531
# Epoch 106/250
# 8/8 [==============================] - 1s 133ms/step - loss: 0.1061 - accuracy: 0.9609
# Epoch 107/250
# 8/8 [==============================] - 1s 155ms/step - loss: 0.0770 - accuracy: 0.9844
# Epoch 108/250
# 8/8 [==============================] - 2s 212ms/step - loss: 0.1567 - accuracy: 0.9609
# Epoch 109/250
# 8/8 [==============================] - 1s 149ms/step - loss: 0.0813 - accuracy: 0.9766
# Epoch 110/250
# 8/8 [==============================] - 3s 356ms/step - loss: 0.0713 - accuracy: 0.9922 - val_loss: 0.4374 - val_accuracy: 0.9087
# Epoch 111/250
# 8/8 [==============================] - 1s 152ms/step - loss: 0.1022 - accuracy: 0.9609
# Epoch 112/250
# 8/8 [==============================] - 1s 147ms/step - loss: 0.0385 - accuracy: 0.9922
# Epoch 226/250
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 227/250
# 8/8 [==============================] - 1s 142ms/step - loss: 0.0429 - accuracy: 0.9922
# Epoch 228/250
# 8/8 [==============================] - 1s 153ms/step - loss: 0.0547 - accuracy: 0.9844
# Epoch 229/250
# 8/8 [==============================] - 1s 161ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 230/250
# 8/8 [==============================] - 2s 285ms/step - loss: 0.0495 - accuracy: 0.9922 - val_loss: 0.5669 - val_accuracy: 0.9107
# Epoch 231/250
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0734 - accuracy: 0.9688
# Epoch 232/250
# 8/8 [==============================] - 1s 139ms/step - loss: 0.0975 - accuracy: 0.9766
# Epoch 233/250
# 8/8 [==============================] - 1s 119ms/step - loss: 0.0832 - accuracy: 0.9688
# Epoch 234/250
# 8/8 [==============================] - 1s 130ms/step - loss: 0.1114 - accuracy: 0.9766
# Epoch 235/250
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0609 - accuracy: 0.9844
# Epoch 236/250
# 8/8 [==============================] - 1s 150ms/step - loss: 0.0639 - accuracy: 0.9844
# Epoch 237/250
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0692 - accuracy: 0.9766
# Epoch 238/250
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0312 - accuracy: 1.0000
# Epoch 239/250
# 8/8 [==============================] - 1s 132ms/step - loss: 0.1231 - accuracy: 0.9766
# Epoch 240/250
# 8/8 [==============================] - 2s 303ms/step - loss: 0.1079 - accuracy: 0.9922 - val_loss: 0.5900 - val_accuracy: 0.8970
# Epoch 241/250
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0613 - accuracy: 0.9922
# Epoch 242/250
# 8/8 [==============================] - 1s 159ms/step - loss: 0.0939 - accuracy: 0.9688
# Epoch 243/250
# 8/8 [==============================] - 1s 161ms/step - loss: 0.0529 - accuracy: 0.9922
# Epoch 244/250
# 8/8 [==============================] - 1s 130ms/step - loss: 0.0607 - accuracy: 0.9922
# Epoch 245/250
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0333 - accuracy: 0.9922
# Epoch 246/250
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0495 - accuracy: 0.9922
# Epoch 247/250
# 8/8 [==============================] - 1s 141ms/step - loss: 0.0561 - accuracy: 0.9844
# Epoch 248/250
# 8/8 [==============================] - 1s 161ms/step - loss: 0.0725 - accuracy: 0.9922
# Epoch 249/250
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1134 - accuracy: 0.9609
# Epoch 250/250
# 8/8 [==============================] - 2s 279ms/step - loss: 0.0334 - accuracy: 1.0000 - val_loss: 0.5121 - val_accuracy: 0.9117
# Model performance:
# 	Train loss:          0.0163
# 	Train accuracy:      100.00
# 	Validation loss:     0.5121
# 	Validation accuracy: 91.17
# Model performance:
# 	Train loss:          0.0163
# 	Train accuracy:      100.00
# 	Test loss:           0.4502
# 	Test accuracy:       91.78
# Accuracy for each run:  [[0.49327964 0.90979999]
#  [0.66380328 0.8915    ]
#  [0.48874083 0.91000003]
#  [0.65096259 0.88020003]
#  [0.4502185  0.91780001]]
# Average accuracy:  [0.54940097 0.90186001]

# %% [markdown]
# ### Tumor classification in digital pathology
# #### Task 3
# In this task, we will look at a more difficult task, using the PatchCamelyon dataset. This contains tissue samples from breast lymph nodes, which could either be healthy or contain tumor tissue, i.e. this is a binary classification problem. For this reason, it is valuable to also evaluate the AU-ROC, which can be passed to Keras as an evaluation metric, 'AUC'.
#
# You are provided with the training and validation set. These have been cropped to 32x32 pixels, to make it a bit less resource demanding to train. The test set is also provided, but without labels.
#
# Your task is to setup a Keras model to achieve the best possible performance on the validation set. You are free to choose how to do this, e.g., by means of regularization and network specifications. You can, for example, use your results from Task 2 as a starting point, but you should also think around how this problem differs from the MNIST classification. For example, in this case the orientation of images has no meaning, so you can randomly flip images both horizontally and vertically. You can also, e.g., explore augmentation by means of changing the image contrast and brightness.
#
# When you are finished with your development, you should run the 'util.pred_test' (at the bottom of the cell), to produce a CSV file with predictions of the test set. The exported CSV file should be uploaded to the Kaggle challenge, as described in the lab information. You need to train the model and export a CSV file 5 times, in order to have a good estimate for your model's performance. There are no requirements on how well your model should perform, as long as it is well above random guessing (50% accuracy).

# %%
from tensorflow import keras
from tensorflow.keras import layers
import util
import data_generator
    
epochs =10
batch_size = 128

# Load the PatchCamyleon dataset
# In this dataset, we don't have labels for the test set.
# Do your development by monitoring the validation performance,
# and when you are finished you will run predictions on the test
# set and produce a CSV file that you can upload to Kaggle.
data = data_generator.DataGenerator()
data.generate(dataset='patchcam')
data.plot()

keras.backend.clear_session()

x = layers.Input(shape=data.x_train.shape[1:])
# Augmentation layer crop
augmented = layers.RandomCrop(height=data.x_train.shape[1], width=data.x_train.shape[2])(x)
augmented = layers.RandomRotation(factor=0.5)(augmented)
augmented = layers.RandomZoom(0.5)(augmented)
augmented = layers.RandomFlip(mode='horizontal')(augmented)
augmented = layers.RandomFlip(mode='vertical')(augmented)
conv1  = conv_block(augmented, N=2, channels=8, kernel_size=(3,3), activation='relu', padding='same')
conv1 = keras.layers.Dropout(0.2)(conv1)
conv2  = conv_block(conv1, N=2, channels=16, kernel_size=(3,3), activation='relu', padding='same')
conv2 = keras.layers.Dropout(0.2)(conv2)
conv3  = conv_block(conv2, N=2, channels=32, kernel_size=(3,3), activation='relu', padding='same')
flat1  = layers.Flatten()(conv3)

dense1 = layers.Dense(512, activation='relu')(flat1)
# dropout layer
dropout = keras.layers.Dropout(0.5)(dense1)
# added kernel_regularizer
y = layers.Dense(data.K, activation='softmax', kernel_regularizer=keras.regularizers.l2(0.00001))(dropout)

model = keras.models.Model(inputs=x, outputs=y)
model.summary()

opt = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy','AUC'])
log = model.fit(data.x_train, data.y_train_oh, batch_size=batch_size, epochs=epochs, 
                validation_data=(data.x_valid, data.y_valid_oh), validation_freq=1,
                verbose=True)

util.evaluate(model, data)
util.plot_training(log)

# TODO: When you have finished your model development, you should 
# run inference on the test set and export a CSV file that can be 
# uploaded to Kaggle
util.pred_test(model, data, name='your_submission6.csv')
# Out:
# Data specification:
# 	Dataset type:           patchcam
# 	Number of classes:      2
# 	Number of channels:     3
# 	Training data shape:    (100000, 32, 32, 3)
# 	Validation data shape:  (32768, 32, 32, 3)
# 	Test data shape:        (32768, 32, 32, 3)
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  random_crop (RandomCrop)    (None, 32, 32, 3)         0
#
#  random_rotation (RandomRota  (None, 32, 32, 3)        0
#  tion)
#
#  random_zoom (RandomZoom)    (None, 32, 32, 3)         0
#
#  random_flip (RandomFlip)    (None, 32, 32, 3)         0
#
#  random_flip_1 (RandomFlip)  (None, 32, 32, 3)         0
#
#  conv2d (Conv2D)             (None, 32, 32, 8)         224
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 8)         584
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 8)        0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 8)         0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 16)        1168
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 16)        2320
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 16)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 16)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 32)          4640
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 32)          9248
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 281,866
# Trainable params: 281,866
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 782/782 [==============================] - 139s 167ms/step - loss: 0.5461 - accuracy: 0.7391 - auc: 0.8063 - val_loss: 0.5778 - val_accuracy: 0.7129 - val_auc: 0.7783
# Epoch 2/10
# 782/782 [==============================] - 131s 167ms/step - loss: 0.5026 - accuracy: 0.7657 - auc: 0.8400 - val_loss: 0.5422 - val_accuracy: 0.7334 - val_auc: 0.8122
# Epoch 3/10
# 782/782 [==============================] - 133s 171ms/step - loss: 0.4863 - accuracy: 0.7741 - auc: 0.8513 - val_loss: 0.5495 - val_accuracy: 0.7225 - val_auc: 0.8094
# Epoch 4/10
# 782/782 [==============================] - 131s 168ms/step - loss: 0.4761 - accuracy: 0.7810 - auc: 0.8584 - val_loss: 0.5407 - val_accuracy: 0.7316 - val_auc: 0.8123
# Epoch 5/10
# 782/782 [==============================] - 127s 163ms/step - loss: 0.4737 - accuracy: 0.7824 - auc: 0.8598 - val_loss: 0.5314 - val_accuracy: 0.7315 - val_auc: 0.8201
# Epoch 6/10
# 782/782 [==============================] - 132s 168ms/step - loss: 0.4702 - accuracy: 0.7833 - auc: 0.8621 - val_loss: 0.5120 - val_accuracy: 0.7448 - val_auc: 0.8319
# Epoch 7/10
# 782/782 [==============================] - 142s 181ms/step - loss: 0.4644 - accuracy: 0.7868 - auc: 0.8658 - val_loss: 0.5167 - val_accuracy: 0.7415 - val_auc: 0.8298
# Epoch 8/10
# 782/782 [==============================] - 154s 197ms/step - loss: 0.4612 - accuracy: 0.7889 - auc: 0.8679 - val_loss: 0.5514 - val_accuracy: 0.7297 - val_auc: 0.8129
# Epoch 9/10
# 782/782 [==============================] - 156s 199ms/step - loss: 0.4595 - accuracy: 0.7906 - auc: 0.8691 - val_loss: 0.4973 - val_accuracy: 0.7571 - val_auc: 0.8437
# Epoch 10/10
# 782/782 [==============================] - 153s 196ms/step - loss: 0.4544 - accuracy: 0.7924 - auc: 0.8724 - val_loss: 0.4974 - val_accuracy: 0.7608 - val_auc: 0.8492
# Model performance:
# 	Train loss:          0.4549
# 	Train accuracy:      79.31
# 	Train AUC:           0.88
# 	Validation loss:     0.4974
# 	Validation accuracy: 76.08
# 	Validation AUC:     0.85
# 1024/1024 [==============================] - 4s 4ms/step
# Done!Please upload your file to Kaggle!
# array([0, 0, 1, ..., 1, 1, 0], dtype=int64)
