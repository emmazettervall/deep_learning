# %% [markdown]
# # TNM112 -- Lab 1
# Instructions about the different tasks are specified in this notebook. However, for more details, please see the PDF with lab instructions. Also see the lab report template for information on how to report your results.

# %% [markdown]
# ### Data generation
# Look through the "data_generator.py" code to understand how the dataset is generated and plotted.
#
# The "importlib" library is used to enable reloading of a library each time the cell is executed (so that changes to the imported script will be visible without restarting the notebook).

# %%
import importlib
import data_generator
importlib.reload(data_generator)

data = data_generator.DataGenerator()
data.generate(dataset='linear', N_train=32, N_test=512, K=4, sigma=0.4)
data.plot()
# Out:
# Data specification:
# 	Dataset type:           linear
# 	Number of classes:      4
# 	Std of classes:         0.4
# 	Training data shape:    (128, 2)
# 	Validation data shape:  (2048, 2)
# 	Test data shape:        (2048, 2)

# %% [markdown]
# ### Keras MLP
# Look through the "keras_mlp.py" code to understand how the model is setup and trained.
#
# #### Task 1.1
# Use a linear dataset with N_train = 512 and K = 2. Specify a network without hidden layers. Compare:
# * Training for 4 epochs with learning rate 1.0 and batch size 512
# * Training for 4 epochs with learning rate 1.0 and batch size 16
#
# Answer the following questions:
# * Which model is best at separating the two classes (provide the accuracy on the test set)? Why is this the case? (Hint: how many iterations of SGD are performed in the two cases?)
# * Why is it possible to do the classification without non-linear activation function (there's only a softmax activation)?
#
# #### Task 1.2
# Use a polar dataset with N_train = 512 and K = 2. Specify a network with one hidden layer with 5 neurons. Train for 20 epochs with learning rate 1.0 and batch size 16. Compare:
# * Using linear activation function
# * Using sigmoid activation function
# * Using relu activation function
#
# Answer the following questions:
# * Why does linear activation not work?
# * On average, what is the best classification accuracy that can be achieved with a linear activation function?
# * Can you find an explanation for the difference comparing sigmoid and relu activation?
#
# #### Task 1.3
# Use a polar dataset with N_train = 512, K = 5, and sigma=0.05. Specify a network with 10 hidden layers with 50 neurons each and relu activation. Try different combinations of hyper parameters to get the best classification accuracy. Examples could be:
# * Change mean and stddev of normal initialization.
# * Change learning rate and add some momentum in SGD.
# * Check the Keras documentation for 'ExponentialDecay', which can be used to specify decaying learning rate for SGD.
# * You can also tweak batch size and number of epochs.
#
# What combination worked best, and what was your best classification accuracy (on the test set)? Can you find any patterns in what combinations of hyper parameters work and doesn't work?
#
# #### Task 1.4
# Continue from previous task, but change initialization to 'glorot_normal' and optimizer to 'keras.optimizers.Adam()'. Does this perform better compared to your results in Task 1.3?

# %%
import keras_mlp
importlib.reload(keras_mlp) 

from tensorflow import keras

# Uncomment to be able to change data specification (instead of having to run the above cell every time)
data.generate(dataset='linear', N_train=512, N_test=512, K=2, sigma=0.1) # Task 1.1
#data.generate(dataset='polar', N_train=512, N_test=512, K=2, sigma=0.1) # Task 1.2
#data.generate(dataset='polar', N_train=512, N_test=512, K=5, sigma=0.05) # Task 1.3

# Hyper-parameters
hidden_layers = 10    # The number of hidden layers in the network (total number of layers will be L=hidden_layers+1)
layer_width = 50       # The number of neurons in each hidden layer
activation = 'relu' # Activation function of hidden layers
#init = keras.initializers.RandomNormal(mean=0.01, stddev=0.1) # Initialization method (starting point for the optimization)
init = keras.initializers.GlorotNormal() # Initialization method (starting point for the optimization)
epochs = 80            # Number of epochs for the training
batch_size = 32        # Batch size to use in training
loss = keras.losses.MeanSquaredError() # Loss function

initial_learning_rate = 0.1
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True)

# Task 1.3 exponential decay
#opt=keras.optimizers.SGD(learning_rate=lr_schedule,
#              momentum=0.9)

#opt = keras.optimizers.SGD(learning_rate=1.0, momentum=0) # Optimizer
# Task 1.4 Adam optimizer
opt = keras.optimizers.Adam(learning_rate=0.001) # Optimizer
# The Keras MLP model
model_k = keras_mlp.KerasMLP(data, verbose=True)

# Setup the model with the specified hyper parameters
model_k.setup_model(hidden_layers=hidden_layers, layer_width=layer_width,
                    activation=activation, init=init)

# Compile the model with a loss function and optimizer
model_k.compile(loss_fn=loss, optimizer=opt)

# Train the model a certain number of epochs with a specified batch size
model_k.train(epochs=epochs, batch_size=batch_size)

# Plot the training progress
model_k.plot_training()

# Evaluate the model (loss and accuracy on the training and test data)
model_k.evaluate()

# Plot the dataset with decision boundaries generated by the trained model
data.plot_classifier(model_k)
# Out:
# Data specification:
# 	Dataset type:           linear
# 	Number of classes:      2
# 	Std of classes:         0.1
# 	Training data shape:    (1024, 2)
# 	Validation data shape:  (1024, 2)
# 	Test data shape:        (1024, 2)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                150
#
#  dense_1 (Dense)             (None, 50)                2550
#
#  dense_2 (Dense)             (None, 50)                2550
#
#  dense_3 (Dense)             (None, 50)                2550
#
#  dense_4 (Dense)             (None, 50)                2550
#
#  dense_5 (Dense)             (None, 50)                2550
#
#  dense_6 (Dense)             (None, 50)                2550
#
#  dense_7 (Dense)             (None, 50)                2550
#
#  dense_8 (Dense)             (None, 50)                2550
#
#  dense_9 (Dense)             (None, 50)                2550
#
#  dense_10 (Dense)            (None, 2)                 102
#
# =================================================================
# Total params: 23,202
# Trainable params: 23,202
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/80
# 32/32 [==============================] - 3s 18ms/step - loss: 0.2306 - accuracy: 0.8340 - val_loss: 0.1498 - val_accuracy: 0.9756
# Epoch 2/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0550 - accuracy: 0.9717 - val_loss: 0.0099 - val_accuracy: 0.9873
# Epoch 3/80
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9951 - val_loss: 0.0098 - val_accuracy: 0.9873
# Epoch 4/80
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9854 - val_loss: 0.0114 - val_accuracy: 0.9863
# Epoch 5/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9971 - val_loss: 0.0095 - val_accuracy: 0.9893
# Epoch 6/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9932 - val_loss: 0.0141 - val_accuracy: 0.9814
# Epoch 7/80
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9893 - val_loss: 0.0160 - val_accuracy: 0.9805
# Epoch 8/80
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9932 - val_loss: 0.0099 - val_accuracy: 0.9883
# Epoch 9/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 0.9951 - val_loss: 0.0102 - val_accuracy: 0.9883
# Epoch 10/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 0.9961 - val_loss: 0.0160 - val_accuracy: 0.9805
# Epoch 11/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9912 - val_loss: 0.0086 - val_accuracy: 0.9893
# Epoch 12/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9922 - val_loss: 0.0116 - val_accuracy: 0.9863
# Epoch 13/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9951 - val_loss: 0.0106 - val_accuracy: 0.9873
# Epoch 14/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 0.9873 - val_loss: 0.0104 - val_accuracy: 0.9873
# Epoch 15/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9912 - val_loss: 0.0107 - val_accuracy: 0.9873
# Epoch 16/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9922 - val_loss: 0.0106 - val_accuracy: 0.9873
# Epoch 17/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 0.9951 - val_loss: 0.0105 - val_accuracy: 0.9883
# Epoch 18/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9971 - val_loss: 0.0107 - val_accuracy: 0.9873
# Epoch 19/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 0.9971 - val_loss: 0.0116 - val_accuracy: 0.9873
# Epoch 20/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 0.9961 - val_loss: 0.0107 - val_accuracy: 0.9883
# Epoch 21/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 0.9971 - val_loss: 0.0099 - val_accuracy: 0.9873
# Epoch 22/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9961 - val_loss: 0.0103 - val_accuracy: 0.9873
# Epoch 23/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 0.9951 - val_loss: 0.0108 - val_accuracy: 0.9873
# Epoch 24/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9893 - val_loss: 0.0121 - val_accuracy: 0.9854
# Epoch 25/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 0.9951 - val_loss: 0.0098 - val_accuracy: 0.9873
# Epoch 26/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9961 - val_loss: 0.0143 - val_accuracy: 0.9805
# Epoch 27/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9932 - val_loss: 0.0109 - val_accuracy: 0.9873
# Epoch 28/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 0.9971 - val_loss: 0.0100 - val_accuracy: 0.9883
# Epoch 29/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9961 - val_loss: 0.0104 - val_accuracy: 0.9883
# Epoch 30/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 0.9961 - val_loss: 0.0103 - val_accuracy: 0.9873
# Epoch 31/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 0.9980 - val_loss: 0.0138 - val_accuracy: 0.9834
# Epoch 32/80
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9932 - val_loss: 0.0109 - val_accuracy: 0.9873
# Epoch 33/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 0.9941 - val_loss: 0.0119 - val_accuracy: 0.9863
# Epoch 34/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 0.9961 - val_loss: 0.0187 - val_accuracy: 0.9795
# Epoch 35/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9912 - val_loss: 0.0206 - val_accuracy: 0.9756
# Epoch 36/80
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9912 - val_loss: 0.0107 - val_accuracy: 0.9873
# Epoch 37/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 0.9971 - val_loss: 0.0114 - val_accuracy: 0.9873
# Epoch 38/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0037 - accuracy: 0.9951 - val_loss: 0.0109 - val_accuracy: 0.9873
# Epoch 39/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 0.9971 - val_loss: 0.0108 - val_accuracy: 0.9873
# Epoch 40/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 0.9951 - val_loss: 0.0109 - val_accuracy: 0.9873
# Epoch 41/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 0.9971 - val_loss: 0.0109 - val_accuracy: 0.9873
# Epoch 42/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 0.9932 - val_loss: 0.0181 - val_accuracy: 0.9805
# Epoch 43/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 0.9941 - val_loss: 0.0155 - val_accuracy: 0.9805
# Epoch 44/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9912 - val_loss: 0.0099 - val_accuracy: 0.9893
# Epoch 45/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 0.9941 - val_loss: 0.0100 - val_accuracy: 0.9883
# Epoch 46/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9922 - val_loss: 0.0095 - val_accuracy: 0.9873
# Epoch 47/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 0.9932 - val_loss: 0.0102 - val_accuracy: 0.9873
# Epoch 48/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 0.9902 - val_loss: 0.0112 - val_accuracy: 0.9873
# Epoch 49/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9922 - val_loss: 0.0093 - val_accuracy: 0.9883
# Epoch 50/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 0.9932 - val_loss: 0.0135 - val_accuracy: 0.9814
# Epoch 51/80
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9932 - val_loss: 0.0166 - val_accuracy: 0.9805
# Epoch 52/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 0.9971 - val_loss: 0.0106 - val_accuracy: 0.9873
# Epoch 53/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 0.9990 - val_loss: 0.0103 - val_accuracy: 0.9893
# Epoch 54/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 0.9922 - val_loss: 0.0095 - val_accuracy: 0.9893
# Epoch 55/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 0.9951 - val_loss: 0.0105 - val_accuracy: 0.9873
# Epoch 56/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 0.9961 - val_loss: 0.0164 - val_accuracy: 0.9805
# Epoch 57/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 0.9922 - val_loss: 0.0148 - val_accuracy: 0.9814
# Epoch 58/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 0.9932 - val_loss: 0.0144 - val_accuracy: 0.9814
# Epoch 59/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 0.9961 - val_loss: 0.0117 - val_accuracy: 0.9863
# Epoch 60/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 0.9961 - val_loss: 0.0108 - val_accuracy: 0.9873
# Epoch 61/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 0.9922 - val_loss: 0.0248 - val_accuracy: 0.9688
# Epoch 62/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 0.9932 - val_loss: 0.0155 - val_accuracy: 0.9805
# Epoch 63/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0037 - accuracy: 0.9961 - val_loss: 0.0097 - val_accuracy: 0.9893
# Epoch 64/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 0.9912 - val_loss: 0.0104 - val_accuracy: 0.9873
# Epoch 65/80
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9941 - val_loss: 0.0096 - val_accuracy: 0.9873
# Epoch 66/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 0.9990 - val_loss: 0.0119 - val_accuracy: 0.9873
# Epoch 67/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 0.9941 - val_loss: 0.0138 - val_accuracy: 0.9834
# Epoch 68/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 0.9980 - val_loss: 0.0107 - val_accuracy: 0.9873
# Epoch 69/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 0.9980 - val_loss: 0.0111 - val_accuracy: 0.9873
# Epoch 70/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 0.9980 - val_loss: 0.0121 - val_accuracy: 0.9873
# Epoch 71/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 0.9971 - val_loss: 0.0112 - val_accuracy: 0.9873
# Epoch 72/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 0.9980 - val_loss: 0.0115 - val_accuracy: 0.9873
# Epoch 73/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 0.9980 - val_loss: 0.0105 - val_accuracy: 0.9893
# Epoch 74/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 0.9971 - val_loss: 0.0115 - val_accuracy: 0.9873
# Epoch 75/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 0.9941 - val_loss: 0.0119 - val_accuracy: 0.9863
# Epoch 76/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 0.9971 - val_loss: 0.0103 - val_accuracy: 0.9873
# Epoch 77/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 0.9980 - val_loss: 0.0108 - val_accuracy: 0.9873
# Epoch 78/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 0.9971 - val_loss: 0.0106 - val_accuracy: 0.9893
# Epoch 79/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 0.9971 - val_loss: 0.0109 - val_accuracy: 0.9873
# Epoch 80/80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 0.9941 - val_loss: 0.0114 - val_accuracy: 0.9863
# Model performance:
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 0.9941
# 	Train loss:     0.0037
# 	Train accuracy: 99.41
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 0.9902
# 	Test loss:      0.0079
# 	Test accuracy:  99.02
# 32/32 [==============================] - 0s 2ms/step
# 512/512 [==============================] - 1s 1ms/step

# %% [markdown]
# ### Our MLP
# To make sure our implementation of the MLP works as intended, we can run inference using the weights we trained with Keras. Then we can see if we get the same results in terms of accuracy and the decision boundaries generated by the model.
#
# #### Task 2
# Implement the "activation", "setup_model", "feedforward", and "evaluate" functions in "mlp.py". Run this cell and compare the results to the results generated by the Keras model in the previous cell (compare number of weights, classification loss/accuracy, and the plots with decision boundaries). Test this for different specifications of the model in the previous cell (number of hidden layers, layer width, and activation function)
#
# #### Task 3
# Use the linear dataset with 2 classes (K=2). Change the specification of the model parameters. Instead of extracting the weights from the Keras model, you should manually specify a weight matrix (2x2) and a bias vector (2x1), i.e. no hidden layers. Remember that each layer is supposed to be an item in a list, which means that you need to specify the weight matrix and the bias vector in separate 1-item lists. As we only have one layer, it will use the 'softmax' activation function.
# * Manually derive weights and biases to specify a model that draws a decision boundary at x2 = 1-x1. What is the simplest possible solution? How many additional solutions are possible?
# * How can you, in the simplest way, change the weights/biases to switch the predicted class labels?
# * By writing out the output of the MLP, motivate why your choice of weights and biases creates a decision boundary at x2 = 1-x1. Can you find a general formula for specifying which combinations of weights and biases will generate the decision boundary?

# %%
import numpy as np
import mlp
importlib.reload(mlp)

# Task 2: Get the weight matrices and biases of the trained Keras model
W, b = model_k.get_weights()

# Task 3: specify a weight matrix and a bias vector
#W = [ np . array ([[ -1 ,0] ,[0 ,1]]) ]
#b = [ np . array ([[1] ,[0]]) ]

# This is our implementation of an MLP, which we set to use the dataset we generated
model = mlp.MLP(data)

# Assign the weights and biases to the MLP and specify the activation function
model.setup_model(W, b, activation=activation)

# Evaluate the model (accuracy on the training and test data)
model.evaluate()

# Plot the dataset with decision boundaries generated by our MLP
data.plot_classifier(model)
# Out:
# Number of hidden layers:  10
# Number of model weights:  550
# Model performance:
# 	Train loss:     0.0037
# 	Train accuracy: 0.99
# 	Test loss:      0.0077
# 	Test accuracy:  0.99

# %%
import numpy as np
import mlp
importlib.reload(mlp)

# Task 2: Get the weight matrices and biases of the trained Keras model
#W, b = model_k.get_weights()

# Task 3: specify a weight matrix and a bias vector
W = [np.array([[-1,0],[0,1]])] 	
b = [np.array([[1],[0]])]

# This is our implementation of an MLP, which we set to use the dataset we generated
model = mlp.MLP(data)

# Assign the weights and biases to the MLP and specify the activation function
model.setup_model(W, b, activation=activation)

# Evaluate the model (accuracy on the training and test data)
model.evaluate()

# Plot the dataset with decision boundaries generated by our MLP
data.plot_classifier(model)
# Out:
# Number of hidden layers:  0
# Number of model weights:  2
# Model performance:
# 	Train loss:     0.1743
# 	Train accuracy: 0.99
# 	Test loss:      0.1756
# 	Test accuracy:  0.99
